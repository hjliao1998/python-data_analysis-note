# %% [markdown]
# # 1、股票市场分析实战——数据获取

# %%
import pandas_datareader as pdr
alibaba = pdr.get_data_yahoo('BABA')

# %%
alibaba.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2015-11-25  82.675003  80.820000  80.910004  81.709999  16330900  81.709999
# 2015-11-27  81.410004  79.275002  80.570000  81.379997  12599900  81.379997
# 2015-11-30  84.470001  81.379997  81.500000  84.080002  97914100  84.080002
# 2015-12-01  84.389999  83.500000  83.769997  84.000000  26235500  84.000000
# 2015-12-02  85.820000  84.250000  84.269997  85.000000  36611500  85.000000

# %%
alibaba.shape
# Out:
# (1258, 6)

# %%
alibaba.tail()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-11-17  260.279999  256.540009  260.279999  256.799988  19739500
# 2020-11-18  258.309998  252.550003  257.760010  255.830002  28307100
# 2020-11-19  261.399994  253.559998  255.000000  259.890015  20752800
# 2020-11-20  272.369995  261.899994  263.970001  270.739990  34115100
# 2020-11-23  275.730011  266.411011  274.750000  270.109985  25180600
#
#              Adj Close
# Date
# 2020-11-17  256.799988
# 2020-11-18  255.830002
# 2020-11-19  259.890015
# 2020-11-20  270.739990
# 2020-11-23  270.109985

# %%
alibaba.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean    161.864959   157.927503   160.044339   159.969706  1.684414e+07
# std      56.481520    54.993905    55.825483    55.817698  9.205313e+06
# min      61.630001    59.250000    60.110001    60.570000  3.775300e+06
# 25%     106.235003   104.368252   105.189999   105.397497  1.106905e+07
# 50%     172.735001   168.900002   171.000000   170.459999  1.478960e+07
# 75%     192.027496   187.240002   189.955002   189.244999  1.996835e+07
# max     319.320007   308.910004   313.500000   317.140015  9.791410e+07
#
#          Adj Close
# count  1258.000000
# mean    159.969706
# std      55.817698
# min      60.570000
# 25%     105.397497
# 50%     170.459999
# 75%     189.244999
# max     317.140015

# %%
alibaba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2015-11-25 to 2020-11-23
# Data columns (total 6 columns):
# High         1258 non-null float64
# Low          1258 non-null float64
# Open         1258 non-null float64
# Close        1258 non-null float64
# Volume       1258 non-null int64
# Adj Close    1258 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 68.8 KB

# %% [markdown]
# # 2、股票市场分析实战——历史趋势分析

# %%
# 基本信息
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# 股票数据的读取
import pandas_datareader as pdr

# 可视化
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# time
from datetime import datetime

# %%
start = datetime(2015,9,20)
alibaba = pdr.get_data_yahoo('BABA', start=start)
amazon = pdr.get_data_yahoo('AMZN', start=start)
'''alibaba = pd.read_csv('D:/Download/新建文件夹/Python3数据科学入门与实战(1)/源码/homework/BABA.csv')
amazon = pd.read_csv('D:/Download/新建文件夹/Python3数据科学入门与实战(1)/源码/homework/AMZN.csv')'''
# Out:
# "alibaba = pd.read_csv('D:/Download/新建文件夹/Python3数据科学入门与实战(1)/源码/homework/BABA.csv')\namazon = pd.read_csv('D:/Download/新建文件夹/Python3数据科学入门与实战(1)/源码/homework/AMZN.csv')"

# %%
alibaba.to_csv('D:/Download/新建文件夹/Python3数据科学入门与实战(1)/源码/homework/BABA.csv')
amazon.to_csv('D:/Download/新建文件夹/Python3数据科学入门与实战(1)/源码/homework/AMZN.csv')

# %%
alibaba.tail()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-11-17  260.279999  256.540009  260.279999  256.799988  19739500
# 2020-11-18  258.309998  252.550003  257.760010  255.830002  28307100
# 2020-11-19  261.399994  253.559998  255.000000  259.890015  20752800
# 2020-11-20  272.369995  261.899994  263.970001  270.739990  34115100
# 2020-11-23  275.730011  266.411011  274.750000  270.109985  25180600
#
#              Adj Close
# Date
# 2020-11-17  256.799988
# 2020-11-18  255.830002
# 2020-11-19  259.890015
# 2020-11-20  270.739990
# 2020-11-23  270.109985

# %%
alibaba['Adj Close'].plot(legend=True)

# %%
alibaba['Volume'].plot(legend=True)

# %%
alibaba['Adj Close'].plot()
amazon['Adj Close'].plot()

# %%
alibaba.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2015-09-21  66.400002  62.959999  65.379997  63.900002  22355100  63.900002
# 2015-09-22  63.270000  61.580002  62.939999  61.900002  14897900  61.900002
# 2015-09-23  62.299999  59.680000  61.959999  60.000000  22684600  60.000000
# 2015-09-24  60.340000  58.209999  59.419998  59.919998  20645700  59.919998
# 2015-09-25  60.840000  58.919998  60.630001  59.240002  17009100  59.240002

# %%
alibaba['high-low'] = alibaba['High'] - alibaba['Low']

# %%
alibaba.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close  \
# Date
# 2015-09-21  66.400002  62.959999  65.379997  63.900002  22355100  63.900002
# 2015-09-22  63.270000  61.580002  62.939999  61.900002  14897900  61.900002
# 2015-09-23  62.299999  59.680000  61.959999  60.000000  22684600  60.000000
# 2015-09-24  60.340000  58.209999  59.419998  59.919998  20645700  59.919998
# 2015-09-25  60.840000  58.919998  60.630001  59.240002  17009100  59.240002
#
#             high-low
# Date
# 2015-09-21  3.440002
# 2015-09-22  1.689999
# 2015-09-23  2.619999
# 2015-09-24  2.130001
# 2015-09-25  1.920002

# %%
alibaba['high-low'].plot()

# %%
# daily return
alibaba['daily-return'] = alibaba['Adj Close'].pct_change()

# %%
alibaba['daily-return'].plot(figsize=(10,4),linestyle='--',marker='o')

# %%
alibaba['daily-return'].plot(kind='hist')

# %%
sns.distplot(alibaba['daily-return'].dropna(),bins=100,color='purple')

# %% [markdown]
# # 3、股票市场分析实战——风险分析

# %%
# 基本信息
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# 股票数据的读取
import pandas_datareader as pdr

# 可视化
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# time
from datetime import datetime

# %%
start = datetime(2015,1,1)
company = ['AAPL','GOOG','MSFT','AMZN','FB']
top_tech_df = pdr.get_data_yahoo(company, start=start)['Adj Close']

# %%
top_tech_df.to_csv('D:/Download/新建文件夹/Python3数据科学入门与实战(1)/源码/homework/top5.csv')

# %%
top_tech_df.head()
# Out:
# Symbols          AAPL        GOOG       MSFT        AMZN         FB
# Date
# 2014-12-31  24.933533  524.958740  41.263744  310.350006  78.019997
# 2015-01-02  24.696352  523.373108  41.539135  308.519989  78.449997
# 2015-01-05  24.000614  512.463013  41.157158  302.190002  77.190002
# 2015-01-06  24.002876  500.585632  40.553074  295.290009  76.150002
# 2015-01-07  24.339447  499.727997  41.068310  298.420013  76.150002

# %%
top_tech_dr = top_tech_df.pct_change()

# %%
top_tech_dr.head()
# Out:
# Symbols         AAPL      GOOG      MSFT      AMZN        FB
# Date
# 2014-12-31       NaN       NaN       NaN       NaN       NaN
# 2015-01-02 -0.009513 -0.003020  0.006674 -0.005897  0.005511
# 2015-01-05 -0.028172 -0.020846 -0.009196 -0.020517 -0.016061
# 2015-01-06  0.000094 -0.023177 -0.014677 -0.022833 -0.013473
# 2015-01-07  0.014022 -0.001713  0.012705  0.010600  0.000000

# %%
top_tech_df.plot()

# %%
top_tech_df[['AAPL','FB','MSFT']].plot()

# %%
sns.jointplot('AMZN','GOOG', top_tech_dr, kind='scatter')

# %%
sns.jointplot('MSFT','FB', top_tech_dr, kind='scatter')

# %%
sns.pairplot(top_tech_dr.dropna())

# %%
top_tech_dr['AAPL'].quantile(0.52)
# Out:
# 0.001476755477962962

# %%
top_tech_dr['MSFT'].quantile(0.05)
# Out:
# -0.026001922683125976

# %%
vips = pdr.get_data_yahoo('VIPS', start=start)['Adj Close']
vips.plot()

# %%
vips.pct_change().quantile(0.2)
# Out:
# -0.022931090679782454
